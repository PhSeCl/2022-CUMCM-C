# %% [markdown]
# # 数学模型仿真实验
#
# 本 Notebook 是建模手交付数学分析后的实验入口。模型实现应放在 `src/cumcm2022c/simulation/`，这里仅负责导入、参数配置、运行和展示。

# %% [markdown]
# ## 1. 导入与数据
# 在模型接口确定后导入项目包和机器可读数据。

# %%
from cumcm2022c.data.load import load_table

# 示例：classified = load_table("form_2")

# %% [markdown]
# ## 2. 参数
# 集中声明随机种子、阈值和实验配置。

# %% [markdown]
# ## 3. 执行
# 调用 `cumcm2022c.simulation` 中经过测试的模型实现。

# %% [markdown]
# ## 4. 结果展示
# 输出表格和图形，并将可交付产物写入 `reports/`。
